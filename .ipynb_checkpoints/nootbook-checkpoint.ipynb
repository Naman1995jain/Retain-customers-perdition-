# %%
import pandas as pd

# %%
DATA_PATH = "DS_Test_Ecofy.docx-EmbeddedFile.xlsm - Customer-Churn.csv"  # <- set this
df = pd.read_csv(DATA_PATH)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# # Analyze the distribution of the target variable 'Churn' using a count plot and explore the relationship between 'Churn' and categorical features by creating stacked bar plots.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Analyze the distribution of the target variable 'Churn'
plt.figure(figsize=(6, 4))
sns.countplot(x='Churn', data=df)
plt.title('Distribution of Churn')
plt.show()

# 2. Explore the relationship between 'Churn' and categorical features
categorical_features = ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
                        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
                        'PaperlessBilling', 'PaymentMethod']

fig, axes = plt.subplots(nrows=len(categorical_features)//3 + 1, ncols=3, figsize=(18, 4 * (len(categorical_features)//3 + 1)))
axes = axes.flatten()

for i, col in enumerate(categorical_features):
    sns.countplot(x=col, hue='Churn', data=df, ax=axes[i])
    axes[i].set_title(f'{col} vs Churn')
    axes[i].tick_params(axis='x', rotation=15)

plt.tight_layout()
plt.show()

# %%
# !pip install optuna
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: optuna in c:\users\dell\appdata\roaming\python\python312\site-packages (4.4.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from optuna) (1.16.4)
# Requirement already satisfied: colorlog in c:\users\dell\appdata\roaming\python\python312\site-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in c:\users\dell\appdata\roaming\python\python312\site-packages (from optuna) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in c:\users\dell\appdata\roaming\python\python312\site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in c:\users\dell\appdata\roaming\python\python312\site-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in c:\users\dell\appdata\roaming\python\python312\site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\dell\appdata\roaming\python\python312\site-packages (from alembic>=1.5.0->optuna) (4.14.1)
# Requirement already satisfied: greenlet>=1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: colorama in c:\users\dell\appdata\roaming\python\python312\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# WARNING: Ignoring invalid distribution ~ransformers (C:\Users\DELL\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (C:\Users\DELL\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (C:\Users\DELL\AppData\Roaming\Python\Python312\site-packages)

# %%
# !pip install pandas numpy scikit-learn xgboost optuna joblib shap matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\dell\appdata\roaming\python\python312\site-packages (2.2.2)
# Requirement already satisfied: numpy in c:\users\dell\appdata\roaming\python\python312\site-packages (2.2.6)
# Requirement already satisfied: scikit-learn in c:\users\dell\appdata\roaming\python\python312\site-packages (1.6.1)
# Requirement already satisfied: xgboost in c:\users\dell\appdata\roaming\python\python312\site-packages (3.0.3)
# Requirement already satisfied: optuna in c:\users\dell\appdata\roaming\python\python312\site-packages (4.4.0)
# Requirement already satisfied: joblib in c:\users\dell\appdata\roaming\python\python312\site-packages (1.4.2)
# Requirement already satisfied: shap in c:\users\dell\appdata\roaming\python\python312\site-packages (0.48.0)
# Requirement already satisfied: matplotlib in c:\users\dell\appdata\roaming\python\python312\site-packages (3.10.0)
# Requirement already satisfied: seaborn in c:\users\dell\appdata\roaming\python\python312\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas) (2025.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.15.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from optuna) (1.16.4)
# Requirement already satisfied: colorlog in c:\users\dell\appdata\roaming\python\python312\site-packages (from optuna) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in c:\users\dell\appdata\roaming\python\python312\site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in c:\users\dell\appdata\roaming\python\python312\site-packages (from optuna) (6.0.2)
# Requirement already satisfied: slicer==0.0.8 in c:\users\dell\appdata\roaming\python\python312\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in c:\users\dell\appdata\roaming\python\python312\site-packages (from shap) (0.61.2)
# Requirement already satisfied: cloudpickle in c:\users\dell\appdata\roaming\python\python312\site-packages (from shap) (3.1.1)
# Requirement already satisfied: typing-extensions in c:\users\dell\appdata\roaming\python\python312\site-packages (from shap) (4.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: Mako in c:\users\dell\appdata\roaming\python\python312\site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from numba>=0.54->shap) (0.44.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: greenlet>=1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: colorama in c:\users\dell\appdata\roaming\python\python312\site-packages (from tqdm->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# WARNING: Ignoring invalid distribution ~ransformers (C:\Users\DELL\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (C:\Users\DELL\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (C:\Users\DELL\AppData\Roaming\Python\Python312\site-packages)

# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, average_precision_score, precision_recall_curve, confusion_matrix, classification_report
from sklearn.calibration import calibration_curve # Import calibration_curve
import xgboost as xgb
import optuna
import joblib
import shap
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set random seed for reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# %%
TARGET = "Churn"  # Expecting values like 'Yes'/'No' or 1/0

# %%
df = pd.read_csv(DATA_PATH)
print("Rows, cols:", df.shape)
print(df.head())
# Out:
# Rows, cols: (7043, 21)
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# # data cleaning to ensure the dataset is ready for analysis. It converts TotalCharges to numeric (handling non-numeric values), normalizes the Churn target to 0/1, and drops irrelevant columns like customerID. A check for unique target values is added to handle unexpected formats. This step ensures data consistency and prepares the dataset for feature engineering and modeling.

# %%
# Quick cleaning
# Convert TotalCharges to numeric
if 'TotalCharges' in df.columns:
    df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# Normalize target to 0/1
print("Unique values in Churn:", df[TARGET].unique())
if df[TARGET].dtype == object:
    df[TARGET] = df[TARGET].str.strip().map({'Yes': 1, 'No': 0}).fillna(df[TARGET])  # Preserve original if mapping fails
    if df[TARGET].isnull().any():
        print("Warning: Some Churn values could not be mapped to 0/1")

# Drop customerID if present
if 'customerID' in df.columns:
    df = df.drop(columns=['customerID'])
# Out:
# Unique values in Churn: ['No' 'Yes']

# %% [markdown]
# # Exploratory Data Analysis

# %%
print(df[TARGET].value_counts(normalize=True))
print(df.isnull().sum())
# Out:
# Churn
# 0    0.73463
# 1    0.26537
# Name: proportion, dtype: float64
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# # Feature Engineering

# %% [raw]
# creates new features to improve model performance. It computes num_services (count of active services) and tenure_bucket (binned tenure values). Standardizing service column values ensures consistency, and the tenure_bucket feature captures non-linear effects of tenure

# %%
# List of service-related columns
service_cols = [
    'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
    'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies'
]
service_cols = [c for c in service_cols if c in df.columns]

# Standardize service column values
for col in service_cols:
    df[col] = df[col].str.lower().replace({'yes': 'yes', 'no': 'no', 'no phone service': 'no', 'no internet service': 'no'})

# Create num_services feature
if service_cols:
    df['num_services'] = df[service_cols].apply(lambda row: sum(row.fillna('no').str.startswith('yes')), axis=1)

# Create tenure_bucket feature
if 'tenure' in df.columns:
    df['tenure_bucket'] = pd.cut(df['tenure'], bins=[-1, 1, 12, 24, 48, 72, 999], labels=['<1', '1-12', '13-24', '25-48', '49-72', '72+'])

# %% [markdown]
# # Feature Selection and Train-Test Split

# %% [raw]
# Numeric and categorical columns are identified, excluding the target and redundant features. A stratified split ensures the target’s class distribution is preserved in both sets, which is critical for imbalanced datasets like churn prediction.

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
num_cols = [c for c in num_cols if c != TARGET]
cat_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()
cat_cols = [c for c in cat_cols if c != TARGET]

print("Numerical features:", num_cols)
print("Categorical features:", cat_cols)

# Train-test split (stratified)
X = df.drop(columns=[TARGET])
y = df[TARGET].astype(int)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=RANDOM_SEED)
# Out:
# Numerical features: ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges', 'num_services']
# Categorical features: ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'tenure_bucket']

# %% [markdown]
# # Preprocessing Pipeline

# %% [raw]
# Numeric features are imputed with the median and scaled, while categorical features are imputed with the most frequent value and one-hot encoded. An ordinal encoder is added for tenure_bucket to handle its ordered nature. The pipeline ensures consistent preprocessing for training and inference.

# %%
# Preprocessing pipeline
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Handle ordinal features like tenure_bucket
ordinal_cols = ['tenure_bucket'] if 'tenure_bucket' in cat_cols else []
nominal_cols = [c for c in cat_cols if c not in ordinal_cols]

preprocessor = ColumnTransformer(transformers=[
    ('num', numeric_transformer, num_cols),
    ('cat', categorical_transformer, nominal_cols),
    ('ord', Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('ordinal', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
    ]), ordinal_cols)
], remainder='drop')

# %% [markdown]
# # Baseline Model (Logistic Regression)

# %% [raw]
# trains and evaluates a baseline logistic regression model with balanced class weights to handle churn’s class imbalance. It computes ROC-AUC and PR-AUC to assess performance. A simple baseline provides a benchmark for comparing more complex models like XGBoost.

# %%
# Baseline: Logistic Regression
baseline = Pipeline(steps=[
    ('preproc', preprocessor),
    ('clf', LogisticRegression(max_iter=1000, class_weight='balanced', random_state=RANDOM_SEED))
])

baseline.fit(X_train, y_train)
y_pred_proba = baseline.predict_proba(X_test)[:, 1]
print("Baseline ROC-AUC:", roc_auc_score(y_test, y_pred_proba))
print("Baseline PR-AUC:", average_precision_score(y_test, y_pred_proba))
# Out:
# Baseline ROC-AUC: 0.8470794905577514
# Baseline PR-AUC: 0.6699140791475463

# %% [markdown]
# # XGBoost Model with Hyperparameter Tuning

# %% [raw]
# This cell defines an Optuna objective function to tune XGBoost hyperparameters, optimizing for ROC-AUC using cross-validation. The tuning process searches for the best parameters to maximize performance, and the best parameters are printed. This step aims to build a stronger model than the baseline.

# %%
# XGBoost with Optuna hyperparameter tuning
def objective(trial):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0),
        'alpha': trial.suggest_float('alpha', 0, 5),
        'lambda': trial.suggest_float('lambda', 0, 5),
        'random_state': RANDOM_SEED,
        'use_label_encoder': False,
        'eval_metric': 'logloss'
    }
    model = Pipeline(steps=[
        ('preproc', preprocessor),
        ('clf', xgb.XGBClassifier(**param, verbosity=0))
    ])
    cv = StratifiedKFold(n_splits=4, shuffle=True, random_state=RANDOM_SEED)
    scores = cross_val_score(model, X_train, y_train, scoring='roc_auc', cv=cv, n_jobs=1)
    return scores.mean()

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50, show_progress_bar=True)
print("Best params:", study.best_params)
# Out:
# [I 2025-08-16 14:40:20,576] A new study created in memory with name: no-name-d4789901-f03a-4ec8-9619-44b0bdd34fc5
# Best trial: 0. Best value: 0.810963:   2%|▉                                             | 1/50 [00:01<00:54,  1.10s/it]
# [I 2025-08-16 14:40:21,687] Trial 0 finished with value: 0.8109627409062465 and parameters: {'n_estimators': 432, 'max_depth': 5, 'learning_rate': 0.28374163414041204, 'subsample': 0.9439751496019357, 'colsample_bytree': 0.5716785538956035, 'alpha': 1.9405822493790064, 'lambda': 4.626471867971212}. Best is trial 0 with value: 0.8109627409062465.
# Best trial: 1. Best value: 0.837265:   4%|█▊                                            | 2/50 [00:03<01:39,  2.08s/it]
# [I 2025-08-16 14:40:24,454] Trial 1 finished with value: 0.837264755617792 and parameters: {'n_estimators': 904, 'max_depth': 11, 'learning_rate': 0.025439239000919177, 'subsample': 0.6122982635972504, 'colsample_bytree': 0.6360017551565142, 'alpha': 4.658556127733108, 'lambda': 2.0746009637846785}. Best is trial 1 with value: 0.837264755617792.
# Best trial: 1. Best value: 0.837265:   6%|██▊                                           | 3/50 [00:05<01:22,  1.75s/it]
# [I 2025-08-16 14:40:25,812] Trial 2 finished with value: 0.8287523736857594 and parameters: {'n_estimators': 750, 'max_depth': 4, 'learning_rate': 0.07180339812054945, 'subsample': 0.7190671675777953, 'colsample_bytree': 0.41945782500746887, 'alpha': 2.0161276794990983, 'lambda': 1.5491860977812533}. Best is trial 1 with value: 0.837264755617792.
# Best trial: 3. Best value: 0.847033:   8%|███▋                                          | 4/50 [00:05<01:01,  1.34s/it]
# [I 2025-08-16 14:40:26,529] Trial 3 finished with value: 0.8470330022143773 and parameters: {'n_estimators': 335, 'max_depth': 3, 'learning_rate': 0.05326124839512125, 'subsample': 0.9456907245062729, 'colsample_bytree': 0.9476866997117309, 'alpha': 4.322328219822279, 'lambda': 1.716045220929432}. Best is trial 3 with value: 0.8470330022143773.
# Best trial: 3. Best value: 0.847033:  10%|████▌                                         | 5/50 [00:08<01:13,  1.63s/it]
# [I 2025-08-16 14:40:28,674] Trial 4 finished with value: 0.8029593631153921 and parameters: {'n_estimators': 552, 'max_depth': 9, 'learning_rate': 0.1640412603989815, 'subsample': 0.980985588773307, 'colsample_bytree': 0.9468213684958379, 'alpha': 1.0083947598095215, 'lambda': 0.5377446767246985}. Best is trial 3 with value: 0.8470330022143773.
# Best trial: 3. Best value: 0.847033:  12%|█████▌                                        | 6/50 [00:09<01:01,  1.39s/it]
# [I 2025-08-16 14:40:29,584] Trial 5 finished with value: 0.8469133392996931 and parameters: {'n_estimators': 155, 'max_depth': 10, 'learning_rate': 0.012680230259987931, 'subsample': 0.8517783295333867, 'colsample_bytree': 0.5328043643414826, 'alpha': 1.546192484905926, 'lambda': 4.849539105631841}. Best is trial 3 with value: 0.8470330022143773.
# Best trial: 6. Best value: 0.847869:  14%|██████▍                                       | 7/50 [00:10<01:02,  1.46s/it]
# [I 2025-08-16 14:40:31,199] Trial 6 finished with value: 0.84786873070642 and parameters: {'n_estimators': 772, 'max_depth': 5, 'learning_rate': 0.010168860590704714, 'subsample': 0.5283497886442436, 'colsample_bytree': 0.478834475461518, 'alpha': 4.079890278984602, 'lambda': 0.27783279187441}. Best is trial 6 with value: 0.84786873070642.
# Best trial: 6. Best value: 0.847869:  16%|███████▎                                      | 8/50 [00:12<01:00,  1.44s/it]
# [I 2025-08-16 14:40:32,606] Trial 7 finished with value: 0.8320257632597503 and parameters: {'n_estimators': 371, 'max_depth': 8, 'learning_rate': 0.051401533024970546, 'subsample': 0.7640425862351492, 'colsample_bytree': 0.6778420000231042, 'alpha': 2.9331067808312787, 'lambda': 3.419026075945497}. Best is trial 6 with value: 0.84786873070642.
# Best trial: 6. Best value: 0.847869:  18%|████████▎                                     | 9/50 [00:13<01:05,  1.61s/it]
# [I 2025-08-16 14:40:34,570] Trial 8 finished with value: 0.8316379243527251 and parameters: {'n_estimators': 624, 'max_depth': 10, 'learning_rate': 0.07618560456367848, 'subsample': 0.8040538793103067, 'colsample_bytree': 0.41932579282062743, 'alpha': 4.48737456536554, 'lambda': 4.532941563532056}. Best is trial 6 with value: 0.84786873070642.
# Best trial: 6. Best value: 0.847869:  20%|█████████                                    | 10/50 [00:18<01:40,  2.52s/it]
# [I 2025-08-16 14:40:39,134] Trial 9 finished with value: 0.8271183644124306 and parameters: {'n_estimators': 932, 'max_depth': 10, 'learning_rate': 0.010168536159427012, 'subsample': 0.7385951718016879, 'colsample_bytree': 0.7177256946526633, 'alpha': 0.1061031327154549, 'lambda': 1.362879145101129}. Best is trial 6 with value: 0.84786873070642.
# Best trial: 6. Best value: 0.847869:  22%|█████████▉                                   | 11/50 [00:20<01:34,  2.42s/it]
# [I 2025-08-16 14:40:41,322] Trial 10 finished with value: 0.837185762530243 and parameters: {'n_estimators': 765, 'max_depth': 6, 'learning_rate': 0.020125023899114653, 'subsample': 0.5210238218534613, 'colsample_bytree': 0.7922151840096864, 'alpha': 3.239602149591069, 'lambda': 0.20559192362666792}. Best is trial 6 with value: 0.84786873070642.
# Best trial: 11. Best value: 0.848898:  24%|██████████▌                                 | 12/50 [00:21<01:10,  1.85s/it]
# [I 2025-08-16 14:40:41,883] Trial 11 finished with value: 0.8488977837597766 and parameters: {'n_estimators': 209, 'max_depth': 3, 'learning_rate': 0.035510053798833915, 'subsample': 0.6289607064849185, 'colsample_bytree': 0.9834211824403978, 'alpha': 3.675059427705746, 'lambda': 2.8797892285115863}. Best is trial 11 with value: 0.8488977837597766.
# Best trial: 11. Best value: 0.848898:  26%|███████████▍                                | 13/50 [00:21<00:54,  1.46s/it]
# [I 2025-08-16 14:40:42,438] Trial 12 finished with value: 0.846697804734956 and parameters: {'n_estimators': 106, 'max_depth': 6, 'learning_rate': 0.02709638543773384, 'subsample': 0.5047543369038244, 'colsample_bytree': 0.816232598948218, 'alpha': 3.5812768081177566, 'lambda': 3.060428275132579}. Best is trial 11 with value: 0.8488977837597766.
# Best trial: 11. Best value: 0.848898:  28%|████████████▎                               | 14/50 [00:23<00:50,  1.39s/it]
# [I 2025-08-16 14:40:43,670] Trial 13 finished with value: 0.8486206410755069 and parameters: {'n_estimators': 711, 'max_depth': 3, 'learning_rate': 0.01801649585711886, 'subsample': 0.6280411646485637, 'colsample_bytree': 0.8516288926517632, 'alpha': 3.813206029031277, 'lambda': 3.270571503208373}. Best is trial 11 with value: 0.8488977837597766.
# Best trial: 11. Best value: 0.848898:  30%|█████████████▏                              | 15/50 [00:23<00:40,  1.17s/it]
# [I 2025-08-16 14:40:44,323] Trial 14 finished with value: 0.8487462342124571 and parameters: {'n_estimators': 269, 'max_depth': 3, 'learning_rate': 0.03465860339988742, 'subsample': 0.6318823059888664, 'colsample_bytree': 0.9964706828143768, 'alpha': 3.809137503922887, 'lambda': 3.4165548169078885}. Best is trial 11 with value: 0.8488977837597766.
# Best trial: 11. Best value: 0.848898:  32%|██████████████                              | 16/50 [00:24<00:34,  1.00s/it]
# [I 2025-08-16 14:40:44,949] Trial 15 finished with value: 0.8483472363165763 and parameters: {'n_estimators': 255, 'max_depth': 3, 'learning_rate': 0.03802012475523148, 'subsample': 0.6372678532080952, 'colsample_bytree': 0.9840707102264583, 'alpha': 2.797977373213624, 'lambda': 3.8881394530546123}. Best is trial 11 with value: 0.8488977837597766.
# Best trial: 11. Best value: 0.848898:  34%|██████████████▉                             | 17/50 [00:25<00:31,  1.05it/s]
# [I 2025-08-16 14:40:45,775] Trial 16 finished with value: 0.835572162536507 and parameters: {'n_estimators': 202, 'max_depth': 7, 'learning_rate': 0.10700788779178497, 'subsample': 0.6811696401215717, 'colsample_bytree': 0.8816935045912468, 'alpha': 4.822311560984506, 'lambda': 2.5685763319999655}. Best is trial 11 with value: 0.8488977837597766.
# Best trial: 11. Best value: 0.848898:  36%|███████████████▊                            | 18/50 [00:26<00:31,  1.01it/s]
# [I 2025-08-16 14:40:46,862] Trial 17 finished with value: 0.844684846360304 and parameters: {'n_estimators': 447, 'max_depth': 4, 'learning_rate': 0.03671643235089465, 'subsample': 0.5786305230649128, 'colsample_bytree': 0.9941220873759682, 'alpha': 3.4517264357128026, 'lambda': 4.098115594646778}. Best is trial 11 with value: 0.8488977837597766.
# Best trial: 11. Best value: 0.848898:  38%|████████████████▋                           | 19/50 [00:28<00:37,  1.22s/it]
# [I 2025-08-16 14:40:48,599] Trial 18 finished with value: 0.8345944811815605 and parameters: {'n_estimators': 291, 'max_depth': 12, 'learning_rate': 0.03861002584657015, 'subsample': 0.679187920443026, 'colsample_bytree': 0.889374897459174, 'alpha': 2.421193831792979, 'lambda': 2.710274417914379}. Best is trial 11 with value: 0.8488977837597766.
# Best trial: 11. Best value: 0.848898:  40%|█████████████████▌                          | 20/50 [00:29<00:35,  1.19s/it]
# [I 2025-08-16 14:40:49,723] Trial 19 finished with value: 0.8386541909063605 and parameters: {'n_estimators': 469, 'max_depth': 4, 'learning_rate': 0.08901550048905721, 'subsample': 0.5857366827233401, 'colsample_bytree': 0.7362705089643082, 'alpha': 4.967881841010702, 'lambda': 3.7501896566686357}. Best is trial 11 with value: 0.8488977837597766.
# Best trial: 11. Best value: 0.848898:  42%|██████████████████▍                         | 21/50 [00:30<00:33,  1.14s/it]
# [I 2025-08-16 14:40:50,758] Trial 20 finished with value: 0.8460876363884189 and parameters: {'n_estimators': 227, 'max_depth': 7, 'learning_rate': 0.019034291028689712, 'subsample': 0.8290103977236478, 'colsample_bytree': 0.9228373382032612, 'alpha': 4.02222238650548, 'lambda': 2.1778120166045563}. Best is trial 11 with value: 0.8488977837597766.
# Best trial: 11. Best value: 0.848898:  44%|███████████████████▎                        | 22/50 [00:31<00:32,  1.17s/it]
# [I 2025-08-16 14:40:51,983] Trial 21 finished with value: 0.8488091612377574 and parameters: {'n_estimators': 653, 'max_depth': 3, 'learning_rate': 0.016324870763846203, 'subsample': 0.6547970809302323, 'colsample_bytree': 0.8377541260261484, 'alpha': 3.848408135775914, 'lambda': 3.1665015956499585}. Best is trial 11 with value: 0.8488977837597766.
# Best trial: 11. Best value: 0.848898:  46%|████████████████████▏                       | 23/50 [00:33<00:36,  1.34s/it]
# [I 2025-08-16 14:40:53,725] Trial 22 finished with value: 0.8403968258010861 and parameters: {'n_estimators': 627, 'max_depth': 5, 'learning_rate': 0.02804394960993871, 'subsample': 0.6747246563432518, 'colsample_bytree': 0.7837339506665612, 'alpha': 3.128046043845422, 'lambda': 2.9546114779954036}. Best is trial 11 with value: 0.8488977837597766.
# Best trial: 23. Best value: 0.849401:  48%|█████████████████████                       | 24/50 [00:34<00:32,  1.26s/it]
# [I 2025-08-16 14:40:54,793] Trial 23 finished with value: 0.8494006649511286 and parameters: {'n_estimators': 542, 'max_depth': 3, 'learning_rate': 0.014545636815128974, 'subsample': 0.5592171785091752, 'colsample_bytree': 0.9045517345206897, 'alpha': 3.7055325845870253, 'lambda': 3.5466550146821305}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  50%|██████████████████████                      | 25/50 [00:35<00:35,  1.41s/it]
# [I 2025-08-16 14:40:56,563] Trial 24 finished with value: 0.8457280117867599 and parameters: {'n_estimators': 850, 'max_depth': 4, 'learning_rate': 0.015741060078668347, 'subsample': 0.5617034748553488, 'colsample_bytree': 0.8481126252478546, 'alpha': 2.645654888372131, 'lambda': 4.296217154183681}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  52%|██████████████████████▉                     | 26/50 [00:37<00:31,  1.32s/it]
# [I 2025-08-16 14:40:57,660] Trial 25 finished with value: 0.8493587184345234 and parameters: {'n_estimators': 551, 'max_depth': 3, 'learning_rate': 0.014752000601078289, 'subsample': 0.5532789863006184, 'colsample_bytree': 0.9011347196416166, 'alpha': 4.21469059934643, 'lambda': 3.622089944182556}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  54%|███████████████████████▊                    | 27/50 [00:38<00:32,  1.42s/it]
# [I 2025-08-16 14:40:59,310] Trial 26 finished with value: 0.8467546446056577 and parameters: {'n_estimators': 526, 'max_depth': 6, 'learning_rate': 0.013645823312896136, 'subsample': 0.5442853856639955, 'colsample_bytree': 0.9259631845976071, 'alpha': 4.3508007140790825, 'lambda': 3.6767358901194176}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  56%|████████████████████████▋                   | 28/50 [00:40<00:31,  1.44s/it]
# [I 2025-08-16 14:41:00,808] Trial 27 finished with value: 0.8437159165416114 and parameters: {'n_estimators': 547, 'max_depth': 5, 'learning_rate': 0.022930771172626103, 'subsample': 0.5953937787875923, 'colsample_bytree': 0.8927056249310341, 'alpha': 3.4135768809845812, 'lambda': 2.782837810814544}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  58%|█████████████████████████▌                  | 29/50 [00:41<00:27,  1.29s/it]
# [I 2025-08-16 14:41:01,744] Trial 28 finished with value: 0.8488298259761471 and parameters: {'n_estimators': 376, 'max_depth': 4, 'learning_rate': 0.012208700883586415, 'subsample': 0.5541731370785925, 'colsample_bytree': 0.7702521906706847, 'alpha': 4.200613782857773, 'lambda': 2.3262580216171855}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  60%|██████████████████████████▍                 | 30/50 [00:42<00:25,  1.25s/it]
# [I 2025-08-16 14:41:02,911] Trial 29 finished with value: 0.8120940997992864 and parameters: {'n_estimators': 491, 'max_depth': 4, 'learning_rate': 0.26577244885316686, 'subsample': 0.5116041113216474, 'colsample_bytree': 0.9561178464478671, 'alpha': 2.372885713896965, 'lambda': 4.997816490830952}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  62%|███████████████████████████▎                | 31/50 [00:43<00:23,  1.23s/it]
# [I 2025-08-16 14:41:04,073] Trial 30 finished with value: 0.839511767152651 and parameters: {'n_estimators': 411, 'max_depth': 5, 'learning_rate': 0.046435947395807725, 'subsample': 0.8848960212168566, 'colsample_bytree': 0.6167606784809071, 'alpha': 3.087275734462697, 'lambda': 4.206798628322229}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  64%|████████████████████████████▏               | 32/50 [00:44<00:20,  1.13s/it]
# [I 2025-08-16 14:41:04,966] Trial 31 finished with value: 0.8489177476043019 and parameters: {'n_estimators': 377, 'max_depth': 3, 'learning_rate': 0.01211504487383241, 'subsample': 0.5525201351966137, 'colsample_bytree': 0.7519308111113489, 'alpha': 4.265752934426241, 'lambda': 2.440892964538194}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  66%|█████████████████████████████               | 33/50 [00:45<00:19,  1.14s/it]
# [I 2025-08-16 14:41:06,126] Trial 32 finished with value: 0.8491767191216535 and parameters: {'n_estimators': 566, 'max_depth': 3, 'learning_rate': 0.01437093229740009, 'subsample': 0.5655939425749625, 'colsample_bytree': 0.9012064510948405, 'alpha': 4.727241678058906, 'lambda': 1.9186799385035744}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  68%|█████████████████████████████▉              | 34/50 [00:46<00:18,  1.16s/it]
# [I 2025-08-16 14:41:07,336] Trial 33 finished with value: 0.8492499389427127 and parameters: {'n_estimators': 587, 'max_depth': 3, 'learning_rate': 0.014349700396695905, 'subsample': 0.5965752187791566, 'colsample_bytree': 0.7534670514046473, 'alpha': 4.635681975565452, 'lambda': 1.019622945868972}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  70%|██████████████████████████████▊             | 35/50 [00:48<00:18,  1.24s/it]
# [I 2025-08-16 14:41:08,755] Trial 34 finished with value: 0.8479187535890484 and parameters: {'n_estimators': 607, 'max_depth': 4, 'learning_rate': 0.015344951297413256, 'subsample': 0.7037503874796874, 'colsample_bytree': 0.6932643843917726, 'alpha': 4.690464302243918, 'lambda': 0.9657160149403046}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  72%|███████████████████████████████▋            | 36/50 [00:49<00:18,  1.29s/it]
# [I 2025-08-16 14:41:10,164] Trial 35 finished with value: 0.8481398558237817 and parameters: {'n_estimators': 691, 'max_depth': 3, 'learning_rate': 0.02282674202794906, 'subsample': 0.6031418040106624, 'colsample_bytree': 0.6411436528739306, 'alpha': 4.657703863432252, 'lambda': 1.7046459046737086}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  74%|████████████████████████████████▌           | 37/50 [00:50<00:16,  1.29s/it]
# [I 2025-08-16 14:41:11,453] Trial 36 finished with value: 0.8472861395810335 and parameters: {'n_estimators': 561, 'max_depth': 4, 'learning_rate': 0.020881534380421774, 'subsample': 0.5857303219678829, 'colsample_bytree': 0.8097102780303665, 'alpha': 4.557199780601286, 'lambda': 1.193503651301585}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  76%|█████████████████████████████████▍          | 38/50 [00:53<00:20,  1.68s/it]
# [I 2025-08-16 14:41:14,032] Trial 37 finished with value: 0.8493144117253654 and parameters: {'n_estimators': 582, 'max_depth': 3, 'learning_rate': 0.013943154367582616, 'subsample': 0.5657927305397344, 'colsample_bytree': 0.9133616873895365, 'alpha': 4.904216706045682, 'lambda': 2.0058235651954446}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  78%|██████████████████████████████████▎         | 39/50 [00:56<00:24,  2.18s/it]
# [I 2025-08-16 14:41:17,401] Trial 38 finished with value: 0.8462931865404155 and parameters: {'n_estimators': 1000, 'max_depth': 5, 'learning_rate': 0.011474312063999296, 'subsample': 0.6079120112122873, 'colsample_bytree': 0.5610404090016083, 'alpha': 4.9832869450727175, 'lambda': 1.0265193274609326}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  80%|███████████████████████████████████▏        | 40/50 [00:59<00:22,  2.25s/it]
# [I 2025-08-16 14:41:19,820] Trial 39 finished with value: 0.8284913930214396 and parameters: {'n_estimators': 502, 'max_depth': 8, 'learning_rate': 0.026988605703505825, 'subsample': 0.5335669020830999, 'colsample_bytree': 0.8571802160879067, 'alpha': 1.4924458754261174, 'lambda': 0.557877338139573}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  82%|████████████████████████████████████        | 41/50 [01:00<00:18,  2.05s/it]
# [I 2025-08-16 14:41:21,379] Trial 40 finished with value: 0.8480700909873515 and parameters: {'n_estimators': 684, 'max_depth': 4, 'learning_rate': 0.010200964175777953, 'subsample': 0.7570877324409738, 'colsample_bytree': 0.9453296739452405, 'alpha': 4.0561977121890544, 'lambda': 0.8407919172219459}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  84%|████████████████████████████████████▉       | 42/50 [01:01<00:14,  1.78s/it]
# [I 2025-08-16 14:41:22,540] Trial 41 finished with value: 0.849096085394951 and parameters: {'n_estimators': 579, 'max_depth': 3, 'learning_rate': 0.014010733946674904, 'subsample': 0.574278336055028, 'colsample_bytree': 0.9216731198629343, 'alpha': 4.458399894899597, 'lambda': 1.9933181373123823}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  86%|█████████████████████████████████████▊      | 43/50 [01:03<00:11,  1.61s/it]
# [I 2025-08-16 14:41:23,741] Trial 42 finished with value: 0.8492634678557811 and parameters: {'n_estimators': 599, 'max_depth': 3, 'learning_rate': 0.017396012964181112, 'subsample': 0.5490942237659499, 'colsample_bytree': 0.8849742297848096, 'alpha': 4.765104041819962, 'lambda': 1.970787729174748}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  88%|██████████████████████████████████████▋     | 44/50 [01:04<00:09,  1.64s/it]
# [I 2025-08-16 14:41:25,457] Trial 43 finished with value: 0.8483403561384388 and parameters: {'n_estimators': 810, 'max_depth': 3, 'learning_rate': 0.017444589453085406, 'subsample': 0.5299653471084645, 'colsample_bytree': 0.8216009617657787, 'alpha': 4.418722276896526, 'lambda': 1.3603415590171826}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  90%|███████████████████████████████████████▌    | 45/50 [01:06<00:08,  1.66s/it]
# [I 2025-08-16 14:41:27,157] Trial 44 finished with value: 0.8485631576367233 and parameters: {'n_estimators': 724, 'max_depth': 4, 'learning_rate': 0.011509512974297736, 'subsample': 0.5049716870865102, 'colsample_bytree': 0.9536145616205669, 'alpha': 4.990180893682408, 'lambda': 1.6475116606250109}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  92%|████████████████████████████████████████▍   | 46/50 [01:08<00:06,  1.70s/it]
# [I 2025-08-16 14:41:28,947] Trial 45 finished with value: 0.8442401856216901 and parameters: {'n_estimators': 652, 'max_depth': 5, 'learning_rate': 0.022676209970863583, 'subsample': 0.6128798414429583, 'colsample_bytree': 0.8647644232702087, 'alpha': 4.09222867251904, 'lambda': 4.543656090197487}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 23. Best value: 0.849401:  94%|█████████████████████████████████████████▎  | 47/50 [01:10<00:05,  1.98s/it]
# [I 2025-08-16 14:41:31,577] Trial 46 finished with value: 0.821865770172709 and parameters: {'n_estimators': 594, 'max_depth': 9, 'learning_rate': 0.031103378875519023, 'subsample': 0.6533550387732787, 'colsample_bytree': 0.45913783330086533, 'alpha': 0.35128596409304436, 'lambda': 1.8472145430112685}. Best is trial 23 with value: 0.8494006649511286.
# Best trial: 47. Best value: 0.849618:  96%|██████████████████████████████████████████▏ | 48/50 [01:12<00:03,  1.70s/it]
# [I 2025-08-16 14:41:32,641] Trial 47 finished with value: 0.8496183585436274 and parameters: {'n_estimators': 515, 'max_depth': 3, 'learning_rate': 0.018265784970061507, 'subsample': 0.5389574655528445, 'colsample_bytree': 0.9151114186847618, 'alpha': 4.7638891333321505, 'lambda': 0.5892673940603439}. Best is trial 47 with value: 0.8496183585436274.
# Best trial: 47. Best value: 0.849618:  98%|███████████████████████████████████████████ | 49/50 [01:13<00:01,  1.59s/it]
# [I 2025-08-16 14:41:33,975] Trial 48 finished with value: 0.8463265946602812 and parameters: {'n_estimators': 414, 'max_depth': 6, 'learning_rate': 0.01854047597319172, 'subsample': 0.5317319826063159, 'colsample_bytree': 0.9693870024096666, 'alpha': 4.820328455778847, 'lambda': 0.6850481450880043}. Best is trial 47 with value: 0.8496183585436274.
# Best trial: 47. Best value: 0.849618: 100%|████████████████████████████████████████████| 50/50 [01:14<00:00,  1.49s/it]
# [I 2025-08-16 14:41:35,132] Trial 49 finished with value: 0.8492946783929954 and parameters: {'n_estimators': 513, 'max_depth': 3, 'learning_rate': 0.010174927905933108, 'subsample': 0.5007201950529373, 'colsample_bytree': 0.9105030277006172, 'alpha': 4.26041048532774, 'lambda': 0.12940658893344364}. Best is trial 47 with value: 0.8496183585436274.
# Best params: {'n_estimators': 515, 'max_depth': 3, 'learning_rate': 0.018265784970061507, 'subsample': 0.5389574655528445, 'colsample_bytree': 0.9151114186847618, 'alpha': 4.7638891333321505, 'lambda': 0.5892673940603439}

# %% [markdown]
# # Train and Evaluate Final XGBoost Model

# %% [raw]
# trains the final XGBoost model using the best parameters from Optuna and evaluates it on the test set. It computes ROC-AUC, PR-AUC, and selects the optimal threshold based on the F1 score. A classification report provides detailed metrics (precision, recall, F1). This step finalizes the model and assesses its performance.

# %%
# Train final model with best params
best_params = study.best_params
final_model = Pipeline(steps=[
    ('preproc', preprocessor),
    ('clf', xgb.XGBClassifier(**best_params, use_label_encoder=False, eval_metric='logloss',
                              verbosity=0, random_state=RANDOM_SEED))
])
final_model.fit(X_train, y_train)
y_test_proba = final_model.predict_proba(X_test)[:, 1]

# Evaluate
print("Final ROC-AUC:", roc_auc_score(y_test, y_test_proba))
print("Final PR-AUC:", average_precision_score(y_test, y_test_proba))

# Threshold selection based on F1 score
precision, recall, thresholds = precision_recall_curve(y_test, y_test_proba)
f1_scores = 2 * (precision * recall) / (precision + recall + 1e-12)
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx] if best_idx < len(thresholds) else 0.5
print("Best threshold by F1:", best_threshold)
y_pred = (y_test_proba >= best_threshold).astype(int)
print(classification_report(y_test, y_pred))
# Out:
# Final ROC-AUC: 0.8488426464129788
# Final PR-AUC: 0.6635459991271663
# Best threshold by F1: 0.3557392
#               precision    recall  f1-score   support
#
#            0       0.89      0.81      0.85      1035
#            1       0.58      0.73      0.64       374
#
#     accuracy                           0.79      1409
#    macro avg       0.73      0.77      0.75      1409
# weighted avg       0.81      0.79      0.79      1409

# %% [markdown]
# # Visualizations

# %% [raw]
# A calibration curve checks how well predicted probabilities align with actual outcomes

# %%
prob_true, prob_pred = calibration_curve(y_test, y_test_proba, n_bins=10)

plt.figure(figsize=(8, 6))
plt.plot(prob_pred, prob_true, marker='o', label='XGBoost')
plt.plot([0, 1], [0, 1], linestyle='--', label='Perfectly calibrated')
plt.xlabel('Mean predicted probability')
plt.ylabel('Fraction of positives')
plt.title('Calibration Curve')
plt.legend()
plt.show() # Displays the plot

# %% [markdown]
# # a confusion matrix visualizes prediction errors

# %% [raw]
# Top-left (834): True Negatives (TN) – The model correctly predicted 834 instances as "No Churn" (0). Top-right (201): False Positives (FP) – The model incorrectly predicted 201 instances as "Churn" (1) when they were actually "No Churn" (0). Bottom-left (100): False Negatives (FN) – The model incorrectly predicted 100 instances as "No Churn" (0) when they were actually "Churn" (1). Bottom-right (274): True Positives (TP) – The model correctly predicted 274 instances as "Churn" (1).

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show() # Displays the plot

# %% [raw]
# SHAP to explain the XGBoost model’s predictions by showing feature importance. Feature names are reconstructed after preprocessing to align with the transformed data. The SHAP summary plot is saved to a file for compatibility, providing insights into which features drive churn predictions.

# %%
# SHAP explainability
preproc = final_model.named_steps['preproc']
X_test_trans = preproc.transform(X_test)

# Reconstruct feature names
feature_names = num_cols
oh = preproc.named_transformers_['cat'].named_steps['onehot']
if hasattr(oh, 'get_feature_names_out'):
    cat_feature_names = list(oh.get_feature_names_out(nominal_cols))
else:
    cat_feature_names = [f"{col}_{val}" for col in nominal_cols for val in oh.categories_[nominal_cols.index(col)]]
feature_names += cat_feature_names

# Compute SHAP values
explainer = shap.Explainer(final_model.named_steps['clf'])
shap_values = explainer(X_test_trans)
shap.summary_plot(shap_values, features=X_test_trans, feature_names=feature_names, show=True)
plt.show()
print("SHAP summary plot")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7684\2520383629.py:17: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values, features=X_test_trans, feature_names=feature_names, show=True)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[69], line 17
#      15 explainer = shap.Explainer(final_model.named_steps['clf'])
#      16 shap_values = explainer(X_test_trans)
# ---> 17 shap.summary_plot(shap_values, features=X_test_trans, feature_names=feature_names, show=True)
#      18 plt.show()
#      19 print("SHAP summary plot")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\shap\plots\_beeswarm.py:1141, in summary_legacy(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, show_values_in_legend, use_log_scale, rng)
#    1139 plt.gca().spines["left"].set_visible(False)
#    1140 plt.gca().tick_params(color=axis_color, labelcolor=axis_color)
# -> 1141 plt.yticks(range(len(feature_order)), [feature_names[i] for i in feature_order], fontsize=13)
#    1142 if plot_type != "bar":
#    1143     plt.gca().tick_params("y", length=20, width=0.5, which="major")
#
# IndexError: list index out of range

# %% [markdown]
# # Save Model

# %%
# Save model
joblib.dump(final_model, "churn_xgb_pipeline.joblib")
print("Saved model to churn_xgb_pipeline.joblib")

# Inference function with input validation
def predict_customers(df_new, model_path="churn_xgb_pipeline.joblib", threshold=best_threshold):
    model = joblib.load(model_path)
    missing_cols = set(X_train.columns) - set(df_new.columns)
    if missing_cols:
        print(f"Warning: Missing columns in input data: {missing_cols}")
    proba = model.predict_proba(df_new)[:, 1]
    return pd.DataFrame({'score': proba, 'predict': (proba >= threshold).astype(int)})
# Out:
# Saved model to churn_xgb_pipeline.joblib

# %% [markdown]
# # Model Testing

# %%
import joblib
import pandas as pd
import numpy as np

# Load the trained pipeline model
model_path = "churn_xgb_pipeline.joblib"
model = joblib.load(model_path)
print("✅ Model loaded successfully")

sample_data = {
    "gender": ["Female"],
    "SeniorCitizen": [0],
    "Partner": ["Yes"],
    "Dependents": ["No"],
    "tenure": [12],
    "PhoneService": ["Yes"],
    "MultipleLines": ["No"],
    "InternetService": ["Fiber optic"],
    "OnlineSecurity": ["No"],
    "OnlineBackup": ["Yes"],
    "DeviceProtection": ["No"],
    "TechSupport": ["No"],
    "StreamingTV": ["Yes"],
    "StreamingMovies": ["No"],
    "Contract": ["Month-to-month"],
    "PaperlessBilling": ["Yes"],
    "PaymentMethod": ["Electronic check"],
    "MonthlyCharges": [70.35],
    "TotalCharges": [845.5],
    "num_services": [3],
    "tenure_bucket": ["1-12"]
}
df_test = pd.DataFrame(sample_data)

# Make predictions
churn_prob = model.predict_proba(df_test)[:, 1]  # churn probability
churn_pred = model.predict(df_test)              # churn label (0/1)

# Add results to DataFrame
df_test["churn_probability"] = churn_prob
df_test["predicted_churn"] = churn_pred

# Show results
print(df_test)
# Out:
# ✅ Model loaded successfully
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No      12          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0            No     Fiber optic             No          Yes  ...
#
#   StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# 0              No  Month-to-month              Yes  Electronic check
#
#   MonthlyCharges TotalCharges num_services  tenure_bucket  churn_probability  \
# 0          70.35        845.5            3           1-12           0.289055
#
#    predicted_churn
# 0                0
#
# [1 rows x 23 columns]
